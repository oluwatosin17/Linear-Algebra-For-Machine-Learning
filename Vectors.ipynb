# %% [markdown]
# ![Screenshot_20200717_165836.jpg](attachment:Screenshot_20200717_165836.jpg)

# %% [markdown]
# This is known as a 2x3 matrix (pronounced "two by three matrix"). The convention in linear algebra is to specify the number of rows first (2) then the number of columns (3).

# %% [markdown]
# Each of the rows and columns in this matrix is represented as a list of numbers. A list of numbers is known as a vector. A row from a matrix is known as a row vector, while a column is known as a column vector. Here are the row vectors from the matrix:

# %% [markdown]
# ![Screenshot_20200717_170338.jpg](attachment:Screenshot_20200717_170338.jpg)

# %% [markdown]
# Here are the column vectors from the matrix:

# %% [markdown]
# ![Screenshot_20200717_170417.jpg](attachment:Screenshot_20200717_170417.jpg)

# %% [markdown]
# ### Geometric Intuition Of Vectors

# %% [markdown]
# Arrows are used to visualize individual vectors because they emphasize the 2 key properties of a vector -- direction and magnitude. The direction of a vector describes the way its pointing while the magnitude describes its length.

# %% [markdown]
# We can visualize vectors in matplotlib using the pyplot.quiver() function. This function has 4 required parameters: X, Y, U, V. X and Y correspond to the x,y coordinates we want the vector to start at and U and V correspond to the x,y coordinates we want the vector to end at. The following code generates an arrow, representing a vector, from 0,0 to 1,2

# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
plt.quiver(0, 0, 1, 2)

plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-3,3)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %% [markdown]
# We also need to set the angles and scale_units parameters to xy and the scale parameter to 1. Setting angles to 'xy' lets matplotlib know we want the angle of the vector to be between the points we specified. The scale_units and scale parameters lets us specify custom scaling parameters for the vectors. When plotting vectors, we always want to use these 3 values for the parameters:

# %% [raw]
# plt.quiver(0, 0, 1, 2, angles='xy', scale_units='xy', scale=1)

# %%
plt.quiver(0, 0, 1, 2, angles='xy', scale_units='xy', scale=1)

plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-3,3)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %% [markdown]
# Lastly, we can set the color of each vector using the color parameter and passing in a string.

# %%
plt.quiver(0, 0, 1, 2, angles='xy', scale_units='xy', scale=1, color='blue')

plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-3,3)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %% [markdown]
# ### Instructions
#
# Add code below the uncommented code to:
# 1. Generate a vector from [0,0] to [2,3] and set its color to 'blue'.
# 2. Generate a vector from [0,0] to [-2,-3] and set its color to 'blue'.
# 3. Generate a vector from [0,0] to [1,1] and set its color to 'gold'.
# 4. Generate a vector from [0,0] to [2,2] and set its color to 'gold'.

# %%
import matplotlib.pyplot as plt
import numpy as np
# This code draws the x and y axis as lines.

plt.quiver(0,0,2,3, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='blue')
plt.quiver(0,0,-2,-3, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='blue')
plt.quiver(0,0,1,1, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='gold')
plt.quiver(0,0,2,2, angles ='xy' ,scale_units = 'xy' ,scale=1,color='gold')


plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-3,3)
plt.ylim(-4,4)
# Out:
# (-4.0, 4.0)

# %% [markdown]
# ### Vector Operations

# %% [markdown]
# Like the rows in a matrix, vectors can be added and subtracted together. When we add or subtract vectors, elements in the same position are added or subtracted and a new vector is created. Here's an example of 2 vectors being added:

# %% [markdown]
# ![Screenshot_20200717_174943.jpg](attachment:Screenshot_20200717_174943.jpg)

# %% [markdown]
# Also same thing for subtraction

# %% [markdown]
# ### Instructions
#
# Add code below the uncommented code to:
# 1. Plot the vector[3,0] . This vector should originate at (0,0).
# 2. Plot the vector[0,3] . This vector should originate at (3,0).
# 3. Add both of these vectors and plot the resulting vector. This vector should originate at (0,0). When calling pyplot.quiver(), use the color parameter to set the color to "green".

# %%
plt.quiver(0,0,3,0, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='blue')
plt.quiver(3,0,0,3, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='blue')
plt.quiver(0,0,3,3, angles = 'xy' ,scale_units = 'xy' ,scale=1,color='green') 
  
plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(-4,4)
plt.ylim(-1,4)
# Out:
# (-1.0, 4.0)

# %% [markdown]
# ### Scaling Vectors

# %% [markdown]
# We can also scale vectors by multiplying or dividing by a scalar (a real number). When we do so, each element in the vector is multiplied or divided by the scalar:

# %% [markdown]
# ![Screenshot_20200717_182028.jpg](attachment:Screenshot_20200717_182028.jpg)

# %% [markdown]
# Between vector addition, vector subtraction, scalar multiplication, and scalar division, we can combine vectors in many different ways. Being able to combine vectors to create other vectors is a key idea in linear algebra. For example, we can combine the following vectors:

# %% [markdown]
# ![Screenshot_20200717_182101.jpg](attachment:Screenshot_20200717_182101.jpg)

# %% [markdown]
# ### Instructions
#
# Add code below the uncommented code to:
# 1. Plot the vector [3,1] . This vector should originate at (0,0) and be colored 'blue'.
# 2. Plot the vector [6,2] . This vector should originate at (0,0) and be colored 'green'.
# 3. Plot the vector [9,3] . This vector should originate at (0,0) and be colored 'orange'.

# %%
# This code draws the x and y axis as lines.
plt.quiver(0,0,3,1, angles = 'xy', scale_units = 'xy', scale =1,color ='blue') 
plt.quiver(0,0,6,2, angles = 'xy', scale_units = 'xy', scale =1,color ='green') 
plt.quiver(0,0,9,3, angles = 'xy', scale_units = 'xy', scale =1,color ='orange') 


plt.axhline(0, c='black', lw=0.5)
plt.axvline(0, c='black', lw=0.5)
plt.xlim(0,10)
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %% [markdown]
# ### Vectors In NumPy

# %%
matrix_one = np.asarray([
    [30, -1, -1000],
    [50, -1, -100]  
], dtype=np.float32)
matrix_one
# Out:
# array([[   30.,    -1., -1000.],
#        [   50.,    -1.,  -100.]], dtype=float32)

# %% [markdown]
# To represent vectors in NumPy, we use the same function but we only specify a single value in each row.

# %%
vector_one = np.asarray([
    [1],
    [2],
    [1]
], dtype=np.float32)
vector_one
# Out:
# array([[1.],
#        [2.],
#        [1.]], dtype=float32)

# %% [markdown]
# As expected, we can use the + and the - operators to perform vector addition and subtraction. In addition, we can use the * operator to multiply a vector by a scalar quantity.

# %%
vector_two = 2*vector_one + 0.5*vector_one

# %%
vector_two
# Out:
# array([[2.5],
#        [5. ],
#        [2.5]], dtype=float32)

# %% [markdown]
# ### Instructions
#
# Assign the following vector to vector_two: [[3,0,1]]
#
# Multiply vector_one by 2, multiply vector_two by 5, and add both of the scaled vectors.
#
# Assign the resulting vector to vector_linear_combination

# %%
vector_two = np.asarray([
    [3],
    [0],
    [1]
], dtype=np.float32)

# %%
vector_one = np.asarray([
    [1],
    [2],
    [1]
], dtype=np.float32)

# %%
vector_linear_combination = (2*vector_one) + (5*vector_two)

# %%
vector_linear_combination
# Out:
# array([[17.],
#        [ 4.],
#        [ 7.]], dtype=float32)

# %% [markdown]
# ### Dot Product

# %% [markdown]
# The last critical vector operation is the dot product. Dot product is similar to multiplication, but involves multiplying the elements in the vectors in a specific way. Both of these vectors need to contain the same number of elements, a requirement the other operations we've learned so far have as well. To compute the dot product, we need to sum the products of the 2 values in each position in each vector:

# %% [markdown]
# ![Screenshot_20200717_230729.jpg](attachment:Screenshot_20200717_230729.jpg)

# %% [markdown]
# ![Screenshot_20200717_230750.jpg](attachment:Screenshot_20200717_230750.jpg)

# %% [markdown]
# Unlike the other vector operations, the result of a dot product is a scalar value, not a vector.

# %% [markdown]
# To compute the dot product between 2 vectors, we need to use the `numpy.dot()` function. This function accepts 2 NumPy ndarray objects as the 2 required parameters. The main quirk is that one of the two vectors need to be represented as a row vector while the other a column vector:

# %%
vector_dp = np.dot(vector_one[:,0], vector_two)

# %%
vector_dp
# Out:
# array([4.], dtype=float32)

# %% [markdown]
# ### Instructions
#
# 1. Compute the dot product between vector_one and vector_two and assign to dot_product.

# %%
vector_one = np.asarray([
    [1],
    [2],
    [1]
], dtype=np.float32)
vector_two = np.asarray([
    [3],
    [0],
    [1]
], dtype=np.float32)
dot_product = np.dot(vector_one[:,0], vector_two)
print(dot_product)
# Out:
# [4.]

# %% [markdown]
# ### Linear Combination

# %% [markdown]
# Being able to scale vectors using scalar multiplication then adding or subtracting these scaled vectors is known as linear combination.

# %% [markdown]
# ### Instructions
#
# Assign the vector [[1,2]]   to w.
#
# Assign the vector [[3,1]]  to v.
#
# Multiply v by 2 and subtract 2 times w and assign the result to end_point.

# %%
w = np.asarray([[1], 
               [2]] , dtype=np.float32) 
v = np.asarray([[3],
                [1]] , dtype=np.float32)
end_point = (2*v)-(2*w)
print(end_point)
# Out:
# [[ 4.]
#  [-2.]]

# %% [markdown]
# ### Linear Combination And Vectors

# %% [markdown]
# Let's circle back to our optimal salary problem. We represented the first offer using the linear function y= 1000 + 30x and the second offer using the linear function y= 100 + 50x . We rewrote these functions in general form. Here's what the first function looks like in general form:

# %% [markdown]
# ![Screenshot_20200717_234912.jpg](attachment:Screenshot_20200717_234912.jpg)

# %% [markdown]
# To represent both linear functions in a system, we used the following augmented matrix:

# %% [markdown]
# ![Screenshot_20200717_235002.jpg](attachment:Screenshot_20200717_235002.jpg)

# %% [markdown]
# ![Screenshot_20200717_235458.jpg](attachment:Screenshot_20200717_235458.jpg)

# %% [markdown]
# ### The Matrix Equation

# %% [markdown]
# ![Screenshot_20200718_000222.jpg](attachment:Screenshot_20200718_000222.jpg)

# %% [markdown]
# On the left side, we're multiplying a matrix containing the coefficients with the vector containing the variables. The right side contains the constant values.

# %% [markdown]
# It's common practice to use x1,x2 ,xn... instead of x and y to represent the individual values in the solution vector

# %% [markdown]
# ![Screenshot_20200718_001218.jpg](attachment:Screenshot_20200718_001218.jpg)
